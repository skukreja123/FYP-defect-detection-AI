# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/defect free/fb3f9bcaaab78bd00839263404.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/defect free/c749d2b4a6cda8640937426245.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/defect free/62fb940ee2aafd701333430642.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/defect free/c4f3e4e04a4ef5610825217905.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/defect free/28095152dd5ecb931237313373.jpg
# ...
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/195.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/255.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/114.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/281.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/43.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/138.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/207.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/209.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/100.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/376.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/13.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/228.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/74.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/323.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/337.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/223.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/350.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/236.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/363.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/68.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/53.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/83.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/336.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/107.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/347.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/354.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/154.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/206.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/164.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/338.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/301.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/146.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/161.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/198.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/277.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/331.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/72.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/257.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/233.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/139.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/318.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/200.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/321.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/32.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/102.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/244.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/220.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/17.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/394.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/157.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/26.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/351.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/183.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/39.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/219.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/373.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/240.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/288.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/360.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/242.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/86.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/229.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/222.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/330.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/15.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/383.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/238.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/119.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/165.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/204.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/12.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/224.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/141.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/92.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/122.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/293.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/305.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/11.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/70.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/210.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/181.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/259.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/389.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/34.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/27.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/370.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/294.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/51.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/262.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/132.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/52.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/341.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/21.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/4.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/309.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/365.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/312.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/184.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/300.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/250.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/297.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/125.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/128.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/172.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/95.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/3.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/36.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/384.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/217.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/386.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/96.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/348.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/144.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/110.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/325.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/385.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/63.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/398.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/162.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/231.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/19.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/201.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/303.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/87.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/47.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/282.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/93.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/170.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/324.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/14.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/18.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/175.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/268.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/345.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/316.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/226.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/116.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/78.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/320.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/367.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/266.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/245.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/335.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/232.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/108.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/49.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/203.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/66.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/298.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/306.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/395.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/307.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/129.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/2.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/205.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/133.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/304.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/315.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/134.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/218.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/249.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/213.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/136.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/364.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/90.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/25.jpg
# /kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/stain/147.jpg

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.utils.class_weight import compute_class_weight
from sklearn.preprocessing import label_binarize
import os

# Dataset parameters
data_dir = '/kaggle/input/fabric-defects-dataset/Fabric Defects Dataset/Fabric Defect Dataset/'
img_size = (64, 64)
batch_size = 32
class_names = ['Vertical', 'defect free', 'hole', 'horizontal', 'lines', 'stain']  # Updated with 6 classes
num_classes = len(class_names)  # Dynamically set based on class_names

# Load and preprocess data
images = []
labels = []

for class_index, class_name in enumerate(class_names):
    class_path = os.path.join(data_dir, class_name)
    if not os.path.exists(class_path):
        print(f"Warning: Directory {class_path} does not exist.")
        continue
    for file_name in os.listdir(class_path):
        file_path = os.path.join(class_path, file_name)
        try:
            img = load_img(file_path, target_size=img_size)
            img_array = img_to_array(img) / 255.0
            images.append(img_array)
            labels.append(class_index)
        except Exception as e:
            print(f"Error loading image {file_path}: {e}")

images = np.array(images)
labels = np.array(labels)

# Validate labels
if np.any(labels >= num_classes):
    raise ValueError(f"Found label greater than expected num_classes ({num_classes - 1})")

# Perform 5 randomized holdout splits
num_splits = 5
results = []

for split in range(num_splits):
    print(f"\nSplit {split + 1}/{num_splits}")

    # Split data into training and validation sets
    X_train, X_val, y_train, y_val = train_test_split(images, labels, test_size=0.2, stratify=labels, random_state=split)

    # Compute class weights
    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_train),
        y=y_train
    )
    class_weights = {i: weight for i, weight in enumerate(class_weights)}

    # One-hot encode labels
    y_train_one_hot = to_categorical(y_train, num_classes=num_classes)
    y_val_one_hot = to_categorical(y_val, num_classes=num_classes)

    # Build Model
    base_model = EfficientNetB0(include_top=False, input_shape=(*img_size, 3), weights='imagenet')
    base_model.trainable = True  # Unfreeze for fine-tuning

    x = GlobalAveragePooling2D()(base_model.output)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)
    output = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=output)

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    # Train the Model
    epochs = 20
    history = model.fit(
        X_train, y_train_one_hot,
        validation_data=(X_val, y_val_one_hot),
        epochs=epochs,
        batch_size=batch_size,
        class_weight=class_weights,
        verbose=1
    )

    # Evaluate Model
    val_preds = model.predict(X_val)
    predicted_classes = np.argmax(val_preds, axis=1)
    true_classes = y_val

    # Classification Report
    print("Classification Report:")
    report = classification_report(true_classes, predicted_classes, target_names=class_names, output_dict=True)
    print(classification_report(true_classes, predicted_classes, target_names=class_names))

    # Confusion Matrix
    conf_matrix = confusion_matrix(true_classes, predicted_classes)
    print("Confusion Matrix:")
    print(conf_matrix)

    # ROC Curve and AUC
    y_val_bin = label_binarize(y_val, classes=range(num_classes))
    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    for i in range(num_classes):
        fpr[i], tpr[i], _ = roc_curve(y_val_bin[:, i], val_preds[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # Plot ROC Curves
    plt.figure(figsize=(8, 6))
    for i in range(num_classes):
        plt.plot(fpr[i], tpr[i], label=f'Class {class_names[i]} (AUC = {roc_auc[i]:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend(loc='lower right')
    plt.show()

    # Store results
    results.append({
        "split": split + 1,
        "history": history.history,
        "classification_report": report,
        "confusion_matrix": conf_matrix,
        "roc_auc": roc_auc
    })

# Plot aggregate metrics
plt.figure(figsize=(12, 5))

# Aggregate Accuracy and Loss
for split_result in results:
    history = split_result["history"]

    # Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history['accuracy'], label=f"Split {split_result['split']} Training")
    plt.plot(history['val_accuracy'], label=f"Split {split_result['split']} Validation")
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Training and Validation Accuracy (Across Splits)')
    plt.legend()

    # Loss
    plt.subplot(1, 2, 2)
    plt.plot(history['loss'], label=f"Split {split_result['split']} Training")
    plt.plot(history['val_loss'], label=f"Split {split_result['split']} Validation")
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss (Across Splits)')
    plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Split 1/5
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 107s 644ms/step - accuracy: 0.6144 - loss: 1.2580 - val_accuracy: 0.0365 - val_loss: 3.7613
# Epoch 2/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8639 - loss: 0.5996 - val_accuracy: 0.0493 - val_loss: 3.4519
# Epoch 3/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.8687 - loss: 0.5805 - val_accuracy: 0.0511 - val_loss: 3.3058
# Epoch 4/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9255 - loss: 0.3115 - val_accuracy: 0.1150 - val_loss: 3.7779
# Epoch 5/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9179 - loss: 0.3688 - val_accuracy: 0.0675 - val_loss: 4.5764
# Epoch 6/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.8791 - loss: 0.4812 - val_accuracy: 0.0639 - val_loss: 4.7746
# Epoch 7/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.8776 - loss: 0.4679 - val_accuracy: 0.1040 - val_loss: 4.7342
# Epoch 8/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9009 - loss: 0.3196 - val_accuracy: 0.2628 - val_loss: 2.8209
# Epoch 9/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.8419 - loss: 0.3865 - val_accuracy: 0.5128 - val_loss: 1.2860
# Epoch 10/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.8979 - loss: 0.3720 - val_accuracy: 0.7172 - val_loss: 1.0001
# Epoch 11/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9258 - loss: 0.2333 - val_accuracy: 0.8759 - val_loss: 0.4234
# Epoch 12/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9347 - loss: 0.2559 - val_accuracy: 0.9033 - val_loss: 0.3125
# Epoch 13/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9419 - loss: 0.1827 - val_accuracy: 0.8485 - val_loss: 0.3696
# Epoch 14/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9259 - loss: 0.2690 - val_accuracy: 0.9380 - val_loss: 0.2184
# Epoch 15/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9368 - loss: 0.2079 - val_accuracy: 0.8923 - val_loss: 0.2910
# Epoch 16/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9419 - loss: 0.2061 - val_accuracy: 0.9453 - val_loss: 0.1499
# Epoch 17/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9628 - loss: 0.1502 - val_accuracy: 0.9471 - val_loss: 0.1904
# Epoch 18/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9473 - loss: 0.1472 - val_accuracy: 0.9380 - val_loss: 0.2214
# Epoch 19/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9428 - loss: 0.2092 - val_accuracy: 0.9325 - val_loss: 0.2500
# Epoch 20/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9400 - loss: 0.1942 - val_accuracy: 0.8029 - val_loss: 0.6648
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 291ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
# Epoch 20/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9455 - loss: 0.1782 - val_accuracy: 0.9398 - val_loss: 0.1830
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 265ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#     Vertical       0.74      0.85      0.79        20
#  defect free       1.00      0.95      0.98       333
#         hole       0.87      0.84      0.85        56
#   horizontal       0.92      0.85      0.88        27
#        lines       0.91      0.94      0.92        32
#        stain       0.84      1.00      0.91        80
#
#     accuracy                           0.94       548
#    macro avg       0.88      0.91      0.89       548
# weighted avg       0.94      0.94      0.94       548
#
# Confusion Matrix:
# [[ 17   0   2   0   1   0]
#  [  0 318   0   0   0  15]
#  [  5   0  47   2   2   0]
#  [  1   0   3  23   0   0]
#  [  0   0   2   0  30   0]
#  [  0   0   0   0   0  80]]
# Split 5/5
# Epoch 1/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 91s 515ms/step - accuracy: 0.6744 - loss: 1.2392 - val_accuracy: 0.1022 - val_loss: 4.4567
# Epoch 2/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8375 - loss: 0.6138 - val_accuracy: 0.6077 - val_loss: 1.3662
# Epoch 3/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8780 - loss: 0.5693 - val_accuracy: 0.0365 - val_loss: 4.1538
# Epoch 4/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9222 - loss: 0.3209 - val_accuracy: 0.1022 - val_loss: 2.2338
# Epoch 5/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9271 - loss: 0.2742 - val_accuracy: 0.0748 - val_loss: 4.0684
# Epoch 6/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9177 - loss: 0.3820 - val_accuracy: 0.1113 - val_loss: 3.7231
# Epoch 7/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9247 - loss: 0.2727 - val_accuracy: 0.1131 - val_loss: 4.2158
# Epoch 8/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9146 - loss: 0.3245 - val_accuracy: 0.1569 - val_loss: 4.2507
# Epoch 9/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9174 - loss: 0.3261 - val_accuracy: 0.3686 - val_loss: 2.5111
# Epoch 10/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9306 - loss: 0.2683 - val_accuracy: 0.5146 - val_loss: 1.0713
# Epoch 11/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9445 - loss: 0.2191 - val_accuracy: 0.8540 - val_loss: 0.4429
# Epoch 12/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9285 - loss: 0.3016 - val_accuracy: 0.8394 - val_loss: 0.4187
# Epoch 13/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9463 - loss: 0.1533 - val_accuracy: 0.9252 - val_loss: 0.2282
# Epoch 14/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9519 - loss: 0.1715 - val_accuracy: 0.9197 - val_loss: 0.2072
# Epoch 15/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9501 - loss: 0.1684 - val_accuracy: 0.9325 - val_loss: 0.2211
# Epoch 16/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9386 - loss: 0.2145 - val_accuracy: 0.7080 - val_loss: 2.7935
# Epoch 17/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9068 - loss: 0.2994 - val_accuracy: 0.4763 - val_loss: 2.4272
# Epoch 18/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9087 - loss: 0.3191 - val_accuracy: 0.9288 - val_loss: 0.3480
# Epoch 19/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9144 - loss: 0.2267 - val_accuracy: 0.9270 - val_loss: 0.3071
# Epoch 20/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9367 - loss: 0.2439 - val_accuracy: 0.9197 - val_loss: 0.5022
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 254ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#     Vertical       0.90      0.45      0.60        20
#  defect free       1.00      0.95      0.98       333
#         hole       0.68      0.98      0.80        56
#   horizontal       0.93      0.48      0.63        27
#        lines       0.91      0.94      0.92        32
#        stain       0.87      0.99      0.92        80
#
#     accuracy                           0.92       548
#    macro avg       0.88      0.80      0.81       548
# weighted avg       0.93      0.92      0.92       548
#
# Confusion Matrix:
# [[  9   0  11   0   0   0]
#  [  1 318   0   1   1  12]
#  [  0   0  55   0   1   0]
#  [  0   0  13  13   1   0]
#  [  0   0   2   0  30   0]
#  [  0   1   0   0   0  79]]
