# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/20.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/6.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/5_processed (3).jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/7_processed (1).jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/7_processed (2).jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/4_processed(3).jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/5.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/8.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/9_processed (2).jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/5_processed (1).jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/10.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/exp2_num_249619 - Copy.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/6_processed (2).jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/9_processed (1).jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/9.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/1.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/8_processed (3).jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/16.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/6_processed (1).jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/7.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/7_processed (3).jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/exp5_num_249786 - Copy.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/22.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/9_processed (3).jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/13.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/exp3_num_249637.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/8_processed (1).jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/17.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/exp1_num_249594.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/15.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/exp2_num_249619.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/12.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/11.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/21.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/4.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/6_processed (3).jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/8_processed (2).jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/5_processed (2).jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/3.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/19.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/exp1_num_249594 - Copy.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/14.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/18.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/exp3_num_249637 - Copy.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/Vertical/2.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/947a857e416e86341212200142.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/b3fd5e7970df61181635096873.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0cd44b30685dbfc40838473185.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/9b72f8ef374548170936074932.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/88c9dca3bd99292e1556152624.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/816cc01996c4f1fc0802419785.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/24b241d52a57821c1056066074.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/aacc701dbf97bf971551184253.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/08e143ee7b1d13ca0943121352.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/1fa7c8738de759421219276085.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/53e119acacdfb14d0925191415.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0e279141bd06a3250934364833.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/1b3e37359e541e831247074685.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/7c321b62d1ededdb1333162361.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/1215c97b412949e01341408343.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/3a0c735938a89d290825319734.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/ff3981f0928fcdca0815072066.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/95408651ac07a85f1332065532.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/fbc2536e9bdab98c1457032473.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/45.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/56.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/20.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/2370b14ed0ede2230902213173.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/00bd30945ae5fb701316505594.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/75ad899c0561b0661344165951.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/eaaf705f6000df951602378052.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/7f78a527a00b18600839085414.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/58.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/fc43f451cfd3093d1553209222.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/6.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/2204da1e8980dfed0800494792.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/d79824349b3a85e90838100744.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/25519b63b5d651081051362813.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/652abcb866cde2a11014147872.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/15ff179b830e4f930955528994.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/6e53b04db815459c1339188542.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/9c68781d2a55c0b21231467143.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/270b50af87ba78401209375335.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/87a141dbb31739001256161754.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/ba66a1ef836600961619147433.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0cb9507a93fb73121232266452.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/572026c9bf1cda9d0921180982.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/bf391035720d02921308198722.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/7665b8af7d4cf3e30809070363.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0016_000_02.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/620e38a3573563f21205061074.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/433679b596ffa0dc1043222783.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/f7238e9267f13e481313289272.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/7a71accc1b696fee1006182272.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0004_000_00.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/3888cd55e2682e431330487282.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/f6ea2a25e102d9540924344554.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/fce35c3f176157341056569824.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0c2635281be8ab7d1238525534.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/4644546bfce8700b0917535905.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0013_000_03.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0003_000_05.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/7b2ab09ece6aaa5a0825573783.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/d84b0e25d8ec00ef0900445992.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/ee99c57fdf0f05d21203104304.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/ceb18e9dbaf74bf91418533684.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/b755f43bfee234640846094884.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/c9f45e74790f07951340048903.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/1a8760be53730e580920045181.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0054b76db19ce3f51301044964.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0006_000_01.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/b52493af124c5e3e0832229194.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/33e9566631fbff4f1342121383.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/dc42798cd56ce1420905235945.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/6c9c56726d41a1530830563644.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/c471a53546c1ef261036170694.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/64b66cfe0f31cc720905235393.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/b31992cbcf4b20940812177224.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/691fcbb1141ac28f1024457543.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/233afd1eafa3056d0941584215.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/a913c4379f1bcd791000291235.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/8702504a5f4a3bb11056481535.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/13757a04c51ab79f1345270733.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/5196bc70dbf947090830172684.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/153221be55ab2a8d0923026711.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/9066d0c054540d6f1446321244.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/b71a02c554dd967f1208100842.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/5.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/8d68179d15ffc1950925191134.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/cb517698953d241c1459414262.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/4762f2d2e3f555321304057285.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/bf0c569f6eb5242f0759373212.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/2d4684430107a5f81606558455.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/96f13144878e4f851232401504.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/8c25cbe269aa33030841096135.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/50dcbedf1c7c30220807460472.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0002_000_01.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0018_000_05.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/382bb7109c51bd4b0957336235.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/22d4d262d82ddee91241583493.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/41b8ae9a977b8b940944238725.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/9440b48be2f5d8400812000242.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0002_000_05.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/8.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/2c371e6ad900fffb1023010482.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/6ceddd0384e924421551576752.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/09a78ad80d7484d41222352782.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/75756d0321e218e41026096273.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/982d475fe45eaee60853531322.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/1744e41be7805f140813438373.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0003_000_06.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/08dfcc16ef87aa781018304252.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/6d77002a36d8eb181332537525.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/4209f17b68d25d081628007212.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/99fbcabb2b7a12df1340231133.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/1d017166671e55e61643344051.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/8e63554dd24808190828540763.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/efe556a3fe014a710846201063.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/1af38ebd4e300b4f1038332364.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/c71d53de1f1bdc0e1027534115.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/39052557c5e244b91334562121.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0017_000_05.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/6a421dae98f7c60f0842086255.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/bcf5b219c08e203c1006182001.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/cc7388f79beb8b5b0934444694.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/fbf05761b7a1f9e60818283105.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/94976be52357593f1601079514.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/1818f22590bbf2fc0905031533.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/e3ab39b0e55df98e0816254905.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/87a08845c98825d61444437853.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/1aacfd1a8bc872531636557353.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/203d2deafe1531201242285632.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/67.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0001_000_02.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/41bbf870aa33d3560814040123.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0b3909e21777032a1050031812.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/378c9f780acfec2c0812176371.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/fed422784b062f780920045733.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0017_000_02.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/09462c6d2c6ab5020939252852.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/6410493304e77a4e0933436402.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/8d267985e731bac31310544123.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/d26ac7168bbd4ef00924344835.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/38a8a7da9927fd4d0941271522.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0009_000_03.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/4320e13f00259c931601470333.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/4a1c3f106d88cf5b0916278993.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/5a9079574da4ab1a0936100603.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/5f19f45266167df90812272134.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/a8fc1cbf3ce2ded11632007214.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/10cf852d520f88f21052412724.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/9c8a3e656fc8b1a60940372513.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/dfde76f7027816981304423494.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/46803f3e04eeaaa51342121102.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/b5d8b59eecb66e760940372232.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/334b972d954ef96d0906525574.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/098f8707886cac3a0945412043.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/30.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/f20208cfb7eb9f141443015214.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/9fd521567a5e5a3c1436167504.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/bf3be9ed0ed73bb91459414784.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/3f37956f686bedf40831341104.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/8d8e538489ba73a00817438872.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/40e16d30be4126e81341177082.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/e191b2f1104286d50905198443.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/62946df2bbde85e51342369561.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/3800975d980aeca80827479894.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/f1fbe80b0fa2ac761310031703.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/ee46ef29b445393c0945048115.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0014_000_01.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/38.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/3d1777d274508ccc1240380592.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/de832fed8e51f68b1634319144.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/b0bbf6094102cb6a0849031482.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0015_000_05.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/116ff371cbda63271241042313.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/9105129a25427bf91315301485.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/f906f874d89db4c11510480153.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/1092bd68c4b484761057440714.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/3d9e12db2b12d3f40832217933.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/c50e1ce727d3eb031331117571.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/42.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0019_000_02.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/2a85f9d5e9d93f251429264364.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/33.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/10.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/54.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/84b7a5f3c11b60ba1629373974.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/41cd869d279e5d6f0824027294.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/62.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0019_000_01.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/4d6cdeac65b443ae0933436131.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/99c381944ff45f891313102263.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/25c54bd352538daf0830002674.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/f926740bdf7f297d1332536712.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/1dad7ed0c753e2b41341407001.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/7368267c682b29a71339188813.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/135d8ef2c9b6be4c0843241112.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/fb93534b292ec14b1207419932.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/138b98d8f5ebf75c1534158954.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/908109d7f6ec8add1336157703.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0008_000_00.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/35.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/dd3b354853cb97021337423032.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/61.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/5245ea42004ccf730920538143.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/3163eca54451fc570906525845.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/35807041ffcb53240812421842.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/c0538b2748bb03c20831319562.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/cd33bc6d181d3bae1633163574.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0011_000_03.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/fb3f9bcaaab78bd00839263404.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/c749d2b4a6cda8640937426245.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/62fb940ee2aafd701333430642.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/c4f3e4e04a4ef5610825217905.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/28095152dd5ecb931237313373.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/809af08c6a3824711208578173.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/5a6c2e2f139d35a01634151184.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0e28071cb38a65150820152983.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/167d4d22a6fcc56d1339090952.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/59.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/fe99c29a2dea1fe80910191992.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/1eebc82f17994fdf1223337804.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/6a015f59f1e012271519506984.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/8e0ea1bd6be633621341408885.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0014_000_00.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/3306e722d95e37ec1308544472.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/3a77305ee4bba0d60944152253.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/7ee2582c3bdd95680821470431.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/22dc46ab5604e7eb0853371531.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/8fa819bcf8bb7f4f1232401785.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/a8308eb8ec094bca0946524735.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/217f9980ea4febf80829405502.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/8341af3f526201211332351212.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/3c41419220dc49251209375054.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/3c2e3d0b145e47921214270802.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/ffe6d7879752f5a81056365526.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0013_000_04.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/37d159a2b324fc6b1214271113.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/99b20655fa4a2d150948168604.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/de81af730886b9881537308552.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/41.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/14355a11031311f40913593512.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/8908cd76e456ebf41342212455.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/540d228b1b6382a70941396903.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/8cd660d15475bc471042044025.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/e75429a2409d755d0828204082.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/cedc091d2e7f5e4f1005080075.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/48beb032fa8df4da0849032315.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/ff8a4978c3fb81aa0828353922.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/328243d3df3683861240285252.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/8e1d68c4bf3a94180914458853.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/7df556ac868765381032084845.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0007_000_02.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/108b9134852fef201024457814.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/259ff1da883a7e4f0825131192.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/096b3ef9df321a880940458611.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/18e25485cd3076331003155635.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/25d1a5b1b7eb8ac81000124763.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/cc87b8e2380de8171052163575.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/8882a615802a88661332066345.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/dd08aa8e4608496a0942324025.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/eff4b64fb6327c2e0914172223.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/955cdfed59206ca60812000513.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/a8ba335f0358c8b61337033081.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0b48b885e2586d2f0943121081.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/29e58e7eea4fc7bf0856492165.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/2190fa4cbebda66d1007568724.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/fec218623a2e7d701237445745.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/4b9f72ebce7627ef0837507063.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/dc68618c4006ae930939588233.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/60.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0003_000_03.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/01c8c576f9c9f0a80944427783.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0e24b4a58674cd730832575613.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/57.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/7155da3dac4a2ba31056066345.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/f06ed4518717c21f1454316264.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/010ec075a90a44f11630314333.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0012_000_05.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/02990142a31bc8560847150035.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/3d85ad44d85fb1a10814428966.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/e652009bbe002c2b0945411772.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/d757faf685b91bb81013262494.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/45b193a2cf9308d50847255825.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/ed96899f408173330918179543.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/9bdc63207e3eb8590811033764.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/a3779dded4de4d891303015624.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/26674566434dfa8a1219095384.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/2098f72cf4c1f2360816254624.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/64fef23598fe0d110805501432.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/d4871b25ccecfad20806357273.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/e6888014574ab2d60911373023.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/9c2d432334af94120940557752.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/cd8dffd3c7eec7951238214985.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/47739d708eed0ac80939371633.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/48ae68ba2b64cfd60829390705.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/9.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/f1adf1fdaab17ea60941583422.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/ade4b4b6ca558f560801537735.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/adc14a81a1f59ddf0841120575.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/31fed14a025417491240087035.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/b79bb760690d06200758289785.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/3b7e2ff6910038691626279525.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/3f1678217aedfdb71234530171.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/cdf2dc38da093bf10939549473.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/d60bde1d4fcb66a91510146884.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/e30a45afee1cbdd80826578364.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0004_000_02.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/81b9be6a15debf741231133793.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/b0a85cf97e3d03780942373202.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/ca4f90df0070b9441220536472.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/5407f2bd678f77540839085143.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/19f8c56dc3f3bf5e1340427933.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/37.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/8e1d180b62bcbc050939189912.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/11a13cefdedba2420945274503.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/3960bc665d5293100907194404.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/b776b6b30c6306871013261952.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/98b7c3b013d561180858076444.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0014_000_02.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/1.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/a78c5155364d853b1342294782.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/b86ed80913f24a091313546823.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/e6215e336eac8c460854359322.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/ad9cdb701a9bf9950924120484.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/d7a70cb3c7b86fec0935217543.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/267aebe83b4570ca1449252132.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/3a0e85f159f1178c1200237324.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/ffd3e9a36956b53a0831030452.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/3ce85210fdd90c590835108753.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0d72f114e34ae0271339324683.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/01a2c80a9b760c4a0948039082.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0005_000_03.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/2e912f259a972b771006390723.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0e813a81bec344750833527673.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/8a4ca5497df631281031588642.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/cede18c7c958502c1057541584.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/d0e9620cef3c191f1247074153.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/25d2b42e37dc24d70917316722.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/0009_000_05.png
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/39c8b6b19e35f3850940080562.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/235211a3f650d9081032084574.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/e9299288bd885fa90836026455.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/2b72970c07ac70ec1602379093.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/93e4cc5e86a10d351340230862.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/57d48a4e50c19d4e1339329081.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/bc2d65f7a8b220bc1203104575.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/defect free/99b61d5a957e577f0942207324.jpg
# ...
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/138.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/207.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/209.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/100.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/376.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/13.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/228.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/74.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/323.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/337.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/223.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/350.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/236.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/363.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/68.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/53.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/83.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/336.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/107.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/347.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/354.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/154.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/206.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/164.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/338.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/301.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/146.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/161.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/198.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/277.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/331.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/72.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/257.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/233.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/139.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/318.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/200.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/321.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/32.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/102.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/244.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/220.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/17.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/394.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/157.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/26.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/351.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/183.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/39.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/219.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/373.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/240.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/288.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/360.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/242.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/86.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/229.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/222.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/330.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/15.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/383.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/238.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/119.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/165.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/204.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/12.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/224.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/141.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/92.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/122.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/293.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/305.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/11.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/70.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/210.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/181.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/259.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/389.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/34.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/27.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/370.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/294.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/51.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/262.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/132.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/52.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/341.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/21.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/4.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/309.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/365.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/312.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/184.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/300.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/250.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/297.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/125.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/128.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/172.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/95.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/3.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/36.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/384.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/217.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/386.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/96.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/348.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/144.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/110.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/325.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/385.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/63.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/398.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/162.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/231.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/19.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/201.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/303.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/87.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/47.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/282.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/93.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/170.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/324.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/14.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/18.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/175.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/268.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/345.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/316.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/226.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/116.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/78.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/320.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/367.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/266.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/245.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/335.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/232.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/108.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/49.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/203.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/66.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/298.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/306.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/395.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/307.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/129.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/2.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/205.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/133.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/304.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/315.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/134.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/218.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/249.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/213.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/136.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/364.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/90.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/25.jpg
# /kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset/stain/147.jpg

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, random_split, WeightedRandomSampler
from torchvision import models, transforms
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.manifold import TSNE
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import os
from torch.optim.lr_scheduler import CosineAnnealingLR
from collections import Counter

# %%
class FabricDefectDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = os.listdir(root_dir)
        self.class_to_idx = {cls: idx for idx, cls in enumerate(self.classes)}
        self.images = self._load_images()

    def _load_images(self):
        images = []
        for cls in self.classes:
            cls_dir = os.path.join(self.root_dir, cls)
            for img_name in os.listdir(cls_dir):
                img_path = os.path.join(cls_dir, img_name)
                images.append((img_path, self.class_to_idx[cls]))
        return images

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path, label = self.images[idx]
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, label

# %%
# Data Augmentation
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
# Load dataset
dataset = FabricDefectDataset(root_dir='/kaggle/input/fabric-defect-dataset/FYP/Fabric Defects Dataset/Fabric Defect Dataset')
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

# %%
# Apply transforms
train_dataset.dataset.transform = train_transform
test_dataset.dataset.transform = test_transform

# %%
# Oversampling with WeightedRandomSampler
train_labels = [label for _, label in train_dataset]
class_counts = Counter(train_labels)
class_weights = {cls: 1.0/class_counts[cls] for cls in class_counts}
sample_weights = [class_weights[label] for label in train_labels]

# Create sampler
max_count = max(class_counts.values())
num_classes = len(class_counts)
total_samples = num_classes * max_count
sampler = WeightedRandomSampler(sample_weights, num_samples=total_samples, replacement=True)

# %%
# Data loaders
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, sampler=sampler)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Vision Transformer model setup
model = models.vit_b_16(pretrained=True)

# Modify classifier head
num_ftrs = model.heads.head.in_features
model.heads.head = nn.Linear(num_ftrs, len(dataset.classes))

# Unfreeze all layers
for param in model.parameters():
    param.requires_grad = True

# Loss function with class weights
class_weights_tensor = torch.tensor([class_weights[i] for i in sorted(class_weights)], dtype=torch.float32)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
class_weights_tensor = class_weights_tensor.to(device)
criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)

# Optimizer and scheduler
optimizer = optim.AdamW(model.parameters(), lr=0.0001)
scheduler = CosineAnnealingLR(optimizer, T_max=15, eta_min=0.00001)

# Training loop
num_epochs = 15
train_losses, test_losses = [], []
train_accs, test_accs = [], []

for epoch in range(num_epochs):
    # Training
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
    
    train_loss = running_loss / len(train_loader)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_accs.append(train_acc)
    
    # Testing
    model.eval()
    test_loss = 0.0
    correct_test = 0
    total_test = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    
    test_loss /= len(test_loader)
    test_acc = 100. * correct_test / total_test
    test_losses.append(test_loss)
    test_accs.append(test_acc)
    
    print(f'Epoch [{epoch+1}/{num_epochs}]')
    print(f'Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}%')
    print(f'Test Loss: {test_loss:.4f} | Test Acc: {test_acc:.2f}%')
    scheduler.step()

# Plotting results
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.title('Loss Curves')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accs, label='Train Acc')
plt.plot(test_accs, label='Test Acc')
plt.title('Accuracy Curves')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

# Save model
torch.save(model.state_dict(), 'ViT_Fabric_Defect.pth')

# Evaluate on the test set and collect embeddings
model.eval()
test_loss = 0.0
correct = 0
total = 0
true_labels, predicted_labels, predictions = [], [], []
embeddings = []

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        
        # Extract embeddings before classification head
        x = model.conv_proj(inputs)
        x = x.flatten(2).transpose(1, 2)
        cls_token = model.class_token.expand(x.shape[0], -1, -1)
        x = torch.cat((cls_token, x), dim=1)
        x = x + model.encoder.pos_embedding
        x = model.encoder(x)
        embeddings.extend(x[:, 0].cpu().numpy())
        
        # Get outputs
        outputs = model(inputs)
        
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        
        true_labels.extend(labels.cpu().numpy())
        predicted_labels.extend(predicted.cpu().numpy())
        predictions.extend(torch.softmax(outputs, dim=1).cpu().numpy())

test_loss /= len(test_loader)
test_acc = 100. * correct / total

print(f"\nTest Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.2f}%")

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=dataset.classes, yticklabels=dataset.classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix - Test Set')
plt.show()

# Classification Report
print("Classification Report - Test Set")
print(classification_report(true_labels, predicted_labels, target_names=dataset.classes))

# ROC/AUC Curve
true_labels_bin = label_binarize(true_labels, classes=np.arange(len(dataset.classes)))

fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(len(dataset.classes)):
    fpr[i], tpr[i], _ = roc_curve(true_labels_bin[:, i], np.array(predictions)[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure()
colors = ['blue', 'red', 'green', 'orange', 'purple']
for i, color in zip(range(len(dataset.classes)), colors):
    plt.plot(fpr[i], tpr[i], color=color, label=f'{dataset.classes[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Test Set')
plt.legend(loc="lower right")
plt.show()

# T-SNE Visualization
embeddings_np = np.array(embeddings)
true_labels_np = np.array(true_labels)

tsne = TSNE(n_components=2, random_state=42, perplexity=30, n_iter=300)
embeddings_2d = tsne.fit_transform(embeddings_np)

plt.figure(figsize=(12, 8))
scatter = plt.scatter(embeddings_2d[:, 0], embeddings_2d[:, 1], 
                     c=true_labels_np, cmap='viridis', alpha=0.7)
plt.title('T-SNE of Test Set Features')
plt.xlabel('TSNE Dimension 1')
plt.ylabel('TSNE Dimension 2')

legend_labels = [plt.Line2D([0], [0], marker='o', color='w', 
                markerfacecolor=scatter.cmap(scatter.norm(i)), 
                markersize=10, label=dataset.classes[i]) 
             for i in range(len(dataset.classes))]
plt.legend(handles=legend_labels, title='Classes')
plt.show()

# Misclassified Images
misclassified_idx = [i for i, (p, t) in enumerate(zip(predicted_labels, true_labels)) if p != t]
for idx in misclassified_idx[:10]:
    true_label = dataset.classes[true_labels[idx]]
    predicted_label = dataset.classes[predicted_labels[idx]]
    probabilities = predictions[idx]

    print(f"\nImage Index: {idx}")
    print(f"True Label: {true_label}")
    print(f"Predicted Label: {predicted_label}")
    print(f"Class Probabilities: {probabilities}")

    img = Image.open(dataset.images[idx][0])
    plt.imshow(img)
    plt.title(f"True: {true_label}, Pred: {predicted_label}")
    plt.xlabel(f"Probs: {probabilities}")
    plt.axis('off')
    plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ViT_B_16_Weights.IMAGENET1K_V1`. You can also use `weights=ViT_B_16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vit_b_16-c867db91.pth" to /root/.cache/torch/hub/checkpoints/vit_b_16-c867db91.pth
# 100%|██████████| 330M/330M [00:01<00:00, 208MB/s]
# Epoch [1/15]
# Train Loss: 0.4134 | Train Acc: 82.57%
# Test Loss: 0.5625 | Test Acc: 92.07%
# Epoch [2/15]
# Train Loss: 0.1403 | Train Acc: 93.96%
# Test Loss: 1.7768 | Test Acc: 28.64%
# Epoch [3/15]
# Train Loss: 0.0814 | Train Acc: 95.12%
# Test Loss: 0.4805 | Test Acc: 90.03%
# Epoch [4/15]
# Train Loss: 0.1946 | Train Acc: 88.96%
# Test Loss: 2.7182 | Test Acc: 1.28%
# Epoch [5/15]
# Train Loss: 1.2104 | Train Acc: 34.38%
# Test Loss: 1.7239 | Test Acc: 23.27%
# Epoch [6/15]
# Train Loss: 0.8652 | Train Acc: 52.60%
# Test Loss: 1.1088 | Test Acc: 27.11%
# Epoch [7/15]
# Train Loss: 0.6432 | Train Acc: 62.25%
# Test Loss: 0.9331 | Test Acc: 55.50%
# Epoch [8/15]
# Train Loss: 0.5114 | Train Acc: 73.06%
# Test Loss: 0.8386 | Test Acc: 66.24%
# Epoch [9/15]
# Train Loss: 0.5103 | Train Acc: 74.84%
# Test Loss: 0.8317 | Test Acc: 70.59%
# Epoch [10/15]
# Train Loss: 0.4593 | Train Acc: 78.61%
# Test Loss: 0.7912 | Test Acc: 75.70%
# Epoch [11/15]
# Train Loss: 0.4306 | Train Acc: 80.47%
# Test Loss: 0.8645 | Test Acc: 76.47%
# Epoch [12/15]
# Train Loss: 0.4207 | Train Acc: 81.93%
# Test Loss: 0.9258 | Test Acc: 73.91%
# Epoch [13/15]
# Train Loss: 0.3651 | Train Acc: 85.19%
# Test Loss: 1.0021 | Test Acc: 83.12%
# Epoch [14/15]
# Train Loss: 0.3246 | Train Acc: 87.14%
# Test Loss: 1.1565 | Test Acc: 83.63%
# Epoch [15/15]
# Train Loss: 0.3247 | Train Acc: 87.95%
# Test Loss: 1.4190 | Test Acc: 82.10%
# Test Loss: 1.4190, Test Accuracy: 82.10%
# Classification Report - Test Set
#               precision    recall  f1-score   support
#
#     Vertical       0.43      0.43      0.43         7
#  defect free       1.00      0.85      0.92       241
#   horizontal       0.33      0.57      0.42         7
#         hole       0.42      0.46      0.44        28
#        lines       0.63      0.63      0.63        30
#        stain       0.73      0.99      0.84        78
#
#     accuracy                           0.82       391
#    macro avg       0.59      0.66      0.61       391
# weighted avg       0.85      0.82      0.83       391
# Image Index: 6
# True Label: defect free
# Predicted Label: stain
# Class Probabilities: [4.2642467e-05 1.6992006e-01 3.5989331e-05 2.2588272e-03 1.0968849e-04
#  8.2763273e-01]
# Image Index: 16
# True Label: hole
# Predicted Label: lines
# Class Probabilities: [1.3779654e-04 2.7222818e-04 9.9220946e-03 1.3517940e-01 8.5437191e-01
#  1.1656593e-04]
# Image Index: 19
# True Label: hole
# Predicted Label: lines
# Class Probabilities: [2.1788590e-03 9.3506853e-05 2.9970646e-01 1.3744834e-02 6.8413043e-01
#  1.4594014e-04]
# Image Index: 22
# True Label: defect free
# Predicted Label: hole
# Class Probabilities: [5.4479202e-05 2.7775386e-01 9.3068855e-05 6.6165733e-01 3.3398364e-02
#  2.7042886e-02]
# Image Index: 23
# True Label: defect free
# Predicted Label: stain
# Class Probabilities: [4.9188534e-06 2.8424686e-02 3.4340476e-06 9.3368239e-05 4.6980995e-06
#  9.7146893e-01]
# Image Index: 30
# True Label: defect free
# Predicted Label: stain
# Class Probabilities: [3.8494695e-06 2.5504263e-02 3.0167585e-06 8.3727879e-05 4.1589833e-06
#  9.7440094e-01]
# Image Index: 68
# True Label: hole
# Predicted Label: Vertical
# Class Probabilities: [8.3275694e-01 2.8807961e-04 6.3995078e-02 1.0213531e-01 7.8747468e-04
#  3.7190162e-05]
# Image Index: 71
# True Label: defect free
# Predicted Label: stain
# Class Probabilities: [2.6762118e-05 7.0872538e-02 3.7977483e-05 5.5080740e-04 5.9901584e-05
#  9.2845196e-01]
# Image Index: 72
# True Label: defect free
# Predicted Label: stain
# Class Probabilities: [6.62395032e-05 2.59641916e-01 1.67990700e-04 1.32514825e-02
#  1.04732369e-03 7.25825071e-01]
# Image Index: 75
# True Label: lines
# Predicted Label: stain
# Class Probabilities: [1.8988580e-05 5.1076651e-02 5.1833900e-05 3.7485579e-04 3.4985951e-05
#  9.4844276e-01]
